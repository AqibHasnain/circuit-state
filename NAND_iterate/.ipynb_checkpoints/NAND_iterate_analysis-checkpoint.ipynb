# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:65% !important; }</style>"))
# Out:
# <style>.container { width:65% !important; }</style>

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy.io import loadmat
import seaborn as sn
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm
from matplotlib.colors import LinearSegmentedColormap
ybp_cmap = LinearSegmentedColormap.from_list(name='ybpcmap', colors=['yellow','black','orchid'])
cmap = LinearSegmentedColormap.from_list(name='GyBu',colors=[[0.85]*3,'mediumblue'])
plt.rcParams.update({'font.size':23}); plt.rcParams.update({'axes.linewidth':1.5}); plt.rc('axes', axisbelow=True);
plt.rc('lines',linewidth=3); plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False 
plt.rcParams['xtick.major.size'] = 8; plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['xtick.major.width'] = 2; plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.major.size'] = 8; plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['ytick.major.width'] = 2; plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.autolimit_mode'] = 'round_numbers'
plt.rcParams['axes.xmargin'] = 0
plt.rcParams['axes.ymargin'] = 0
figDir = '/Users/aqib/Desktop/BCCL/char-syn-gene-nets/MSB_submission/figures/'

import seaborn as sns
import cvxpy
import time
import scanpy as sc
from copy import deepcopy
from collections import Counter
import re
import json

# %%
def concat_metadata2tpmdata(dftpm,dfmd):
    # add the metadata to the tpm data

    # find the rows of the metadata which correspond to the columns of the tpm data
    metalist = list(dfmd['sample_id'])
    dfmd_match_rowInd = []
    dftpm_match_colInd = []
    sid_count = 1
    for sid in dftpm.iloc[:,1:]:
        dfmd_match_rowInd.append(metalist.index(sid))
        dftpm_match_colInd.append(sid_count)
        sid_count = sid_count + 1
    # dfmd.iloc[dfmd_match_rowInd,:]

    # rename the row indices with the gene names
    dftpm_geneindex = dftpm.set_index('gene_id')
    dftpm_geneindex.index.names = [None]
    # dftpm_geneindex

    # create a dataframe, md2append, which contains just the metadata that correponds to the experiments in tpm data
    sids = list(dftpm_geneindex.columns)
    md2append = dfmd.T.iloc[:,dfmd_match_rowInd]
    md2append.columns = sids

    # concatenate the metadata to the top of the columns of tpm data
    dftpm_final = pd.concat([md2append,dftpm_geneindex[:]])
    # dftpm_final
    
    return(dftpm_final)

# %% [markdown]
# ### Load data and metadata

# %%
df_tpm1 = pd.read_csv('ReadCountMatrix_preCAD_TPM_NANDiterate_1.tsv', sep='\t') # replicates 1,2,3,4 if they exist
df_tpm2 = pd.read_csv('ReadCountMatrix_preCAD_TPM_NANDiterate_2.tsv', sep='\t') # replicates 5,6,7,8 if they exist
df_metadata = pd.read_csv('NANDiterate_metadata.csv', sep=',')

# %%
df_tpm1_final = concat_metadata2tpmdata(df_tpm1,df_metadata)
df_tpm2_final = concat_metadata2tpmdata(df_tpm2,df_metadata)
df_tpm_final = pd.concat([df_tpm1_final,df_tpm2_final],axis=1)

# %% [markdown]
# # TO-DO: remove rsd and fecA from host genes and circuit genes

# %% [markdown]
# ### Remove samples with NaN values

# %%
sample_inds_with_nans = list(set(np.where(np.isnan(np.array(df_tpm_final.iloc[10:,:],dtype=np.float32)))[1]))
sample_with_nans = list(df_tpm_final.columns)[sample_inds_with_nans[0]]
df_tpm_final = df_tpm_final.drop(columns=[sample_with_nans],axis=1)

# %% [markdown]
# ### Generate AnnData object

# %%
obs_df = df_tpm_final.T.loc[:,['sample_id','timepoint','strain','temperature','replicate',
                               'arabinose_concentration','arabinose_unit','IPTG_concentration',
                               'IPTG_unit','strain_input_state']]
adata = sc.AnnData(np.array(df_tpm_final.T.iloc[:,10:],dtype=np.float32),obs=obs_df)
adata.var_names = list(df_tpm_final.index)[10:]

input_state = []
aras = np.sort(adata.obs.arabinose_concentration.unique())
iptgs = np.sort(adata.obs.IPTG_concentration.unique())
for ii, (ara,iptg) in enumerate(zip(adata.obs.arabinose_concentration,adata.obs.IPTG_concentration)):  

    if ara == aras[0]: 
        input_state.append( '(ara none,' )
    elif ara == aras[1]:
        input_state.append( '(ara low,' )
    elif ara == aras[2]:
        input_state.append( '(ara mid,'  ) 
    elif ara == aras[3]:
        input_state.append( '(ara high,' )
    
    if iptg == iptgs[0]: 
        input_state[ii] += ' IPTG none)'
    elif iptg == iptgs[1]:
        input_state[ii] += ' IPTG low)'
    elif iptg == iptgs[2]:
        input_state[ii] += ' IPTG mid)'   
    elif iptg == iptgs[3]:
        input_state[ii] += ' IPTG high)'
        
adata.obs['strain_input_state'] = input_state
adata.obs['timepoint'] = adata.obs['timepoint'].astype(str)
adata.obs['temperature'] = adata.obs['temperature'].astype(str)

sc.pp.log1p(adata)

# %% [markdown]
# ### Remove plasmid strains from object

# %%
adata = adata[~adata.obs.strain.isin(['MG1655_pJS007_LALT__backbone','MG1655_pJS007_LALT__P3__PhlF',
                                     'MG1655_pJS007_LALT__I1__IcaRA'])].copy()

# %% [markdown]
# ### Create a new AnnData object without circuit genes

# %%
bdata = adata[:,0:-13].copy() # remove circuit genes since they will bias results

# %% [markdown]
# ### TF-GENE network

# %%
tf_gene_df = pd.read_csv('TF-Gene_network_Ecoli_K12.csv',index_col=0).reset_index(drop=True)

# %% [markdown]
# Get list of TFs that are in the RNA-seq dataset

# %%
N_ALL_GENES = len(bdata.var_names.tolist()) # n endogenous genes in RNA-seq data
db_TFs = tf_gene_df.regulator.tolist() # list of TFs from RegulonDB
db_TFs = [x[0].lower() + x[1:] for x in db_TFs] # set the TF names to lowercase
TFs = list(set(bdata.var_names.tolist()).intersection(db_TFs)) # get the TFs that are in the RNA-seq data
tf_gene_df = tf_gene_df.loc[list(np.where(pd.DataFrame(db_TFs)[0].isin(TFs))[0])] # subset tf_gene_df accordingly
N_TFs = len(tf_gene_df.regulator.unique()) # n TFs that are in the RNA-seq data

# %% [markdown]
# Build the adjacency matrix

# %%
tf_adj_df = pd.DataFrame(np.zeros((N_TFs,N_ALL_GENES)))
tf_adj_df = tf_adj_df.set_index(tf_gene_df.regulator.unique())
tf_adj_df.columns = bdata.var_names.tolist()
for ii, tf in enumerate(tf_adj_df.index):
    # get the portion of the df that has 'tf' as regulator
    this_tf_gene = tf_gene_df[tf_gene_df.regulator.isin([tf])] 
    # get the regulated genes for 'tf'
    regulated_genes = this_tf_gene.regulated.tolist()
    # remove any genes that are not in 'tf_adj_df.columns'
    subset_regulated_genes = tf_adj_df.loc[tf,tf_adj_df.columns.isin(regulated_genes)].index.tolist() 
    # get the effect of 'tf' on 'subset_regulated_genes'
    this_tf_gene = this_tf_gene[this_tf_gene.regulated.isin(subset_regulated_genes)]
    # the database may contain duplicate entries, keep only one of them
    dups = [k for (k,v) in Counter(this_tf_gene.regulated.tolist()).items() if v > 1]
    dups_ind = this_tf_gene[this_tf_gene.regulated.isin(dups)].index.tolist()[1:]
    this_tf_gene = this_tf_gene.drop(labels=dups_ind,axis=0)
    # grab the effect labels
    this_effect = this_tf_gene.effect.tolist()
    # change any nan to 0, any '+' to 1, any '-' to -1, and any '+/-' to 2
    this_effect = ['0' if x is np.nan else x for x in this_effect]
    this_effect = ['1' if x == '+' else x for x in this_effect] 
    this_effect = ['-1' if x == '-' else x for x in this_effect]
    this_effect = ['2' if x == '+/-' else x for x in this_effect]    
    this_effect = [int(x) for x in this_effect]
    # write this to the adjacency matrix
    tf_adj_df.loc[tf,subset_regulated_genes] = this_effect

# %%
tdata = bdata[:,TFs].copy()

# %% [markdown]
# ### SIGMA - GENE network

# %%
sigma_gene_df = pd.read_csv('network_sigma_gene.txt',sep='\t',header=None).iloc[:,[0,1,2]]
sigma_gene_df.columns = ['regulator','regulated','effect']

# %%
sigma_adj_df = pd.DataFrame(np.zeros((len(set(sigma_gene_df['regulator'])),N_ALL_GENES)))
sigma_adj_df = sigma_adj_df.set_index(sigma_gene_df.regulator.unique())
sigma_adj_df.columns = bdata.var_names.tolist()

# %%
for ii, sigma in enumerate(sigma_adj_df.index):
    # get the portion of the df that has 'sigma' as regulator
    this_sigma_gene = sigma_gene_df[sigma_gene_df.regulator.isin([sigma])]
    # get the regulated genes for 'sigma'
    regulated_genes = this_sigma_gene.regulated.tolist()
    # remove any genes that are not in 'sigma_adj.columns'
    subset_regulated_genes = sigma_adj_df.loc[sigma,sigma_adj_df.columns.isin(regulated_genes)].index.tolist()
    # get the effect of 'tf' on 'subset_regulated_genes'
    this_sigma_gene = this_sigma_gene[this_sigma_gene.regulated.isin(subset_regulated_genes)]
    # grab the effect labels
    this_effect = this_sigma_gene.effect.tolist()
    # change any nan to 0, any '+' to 1, any '-' to -1, and any '+/-' to 2
    this_effect = ['0' if x is np.nan else x for x in this_effect]
    this_effect = ['1' if x == '+' else x for x in this_effect] 
    this_effect = ['-1' if x == '-' else x for x in this_effect]
    this_effect = ['2' if x == '+/-' else x for x in this_effect]    
    this_effect = [int(x) for x in this_effect]
    # write this to the adjacency matrix
    sigma_adj_df.loc[sigma,subset_regulated_genes] = this_effect

# %% [markdown]
# ### Essential genes

# %%
ess_df = pd.read_csv('deg_annotation_p.csv', sep=';', header=None,quotechar='"')
ess_df.columns = ['organism_id','gene_id','gene','protein_id?','?','biological process',
                   'biological function','bacteria','genome_ref','media','locus_tag','GO_id','??','???']
essential_genes = list(set(ess_df[ess_df.bacteria.isin(['Escherichia coli MG1655 I'])].gene))
# many of genes come as a pair of genes in a single string 'gene1/gene2', separate them
essential_genes_new = []
for gene in essential_genes:
    if '/' in gene: 
        two_genes = gene.split('/')
        essential_genes_new += two_genes
    else: 
        essential_genes_new.append(gene)
essential_genes = essential_genes_new
essential_genes = list(set(essential_genes).intersection(list(bdata.var_names)))
edata = bdata[:,essential_genes].copy()

# %% [markdown]
# ### Plot interesting genes in a heatmap
# These markers came from preliminary analysis.

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

circuit_markers = ['mepM','ykgL','ykgM','ykgO','zinT','znuA','znuB','znuC','pliG',
                   'ompR','narZ','narW','narV','narY','dtpA','envZ','ymdF']
                   #'nrdE','aroH','dnaK','yghW','modC','cysW','yciW','yedE']
fig = sc.pl.heatmap(adata, var_names=circuit_markers, 
              groupby=['strain','timepoint'],
              swap_axes=True,figsize=(20,8),
              cmap='viridis',standard_scale='var',dendrogram=False)

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;

# %% [markdown]
# ### mepM is interesting!
# Using STRING-DB (https://string-db.org/cgi/network?taskId=b1PSR9GvKaDD&sessionId=bdIHtsFSnaBV) we can identify associated genes. Plot those along with mepM

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

circuit_markers = ['mepM','znuA','mepH','lpxM','mepS','mltD','amiB','znuC','amiC','yibQ','znuB']
fig = sc.pl.heatmap(adata, var_names=circuit_markers, 
              groupby=['strain'],
              swap_axes=False,figsize=(4.5,5),
              cmap='viridis',standard_scale='var') # ,save='_mepM-network.pdf'

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;

# %%
# group by strain and plot mepM

plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
sc.pl.violin(adata,keys=['mepM'],groupby='strain',rotation=90) # ,save='_mepM.pdf'
plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True;

# %%
# which genes are correlated with mepM (use bdata so as not to correlate with circuit genes)
tpm_df = pd.DataFrame(bdata.X,columns=bdata.var_names.tolist())
corr_mepM = np.array(tpm_df.corrwith(tpm_df['mepM']))

corr_cutoff = 0.6
mepM_corr_genes = list(bdata.var_names[np.where(np.abs(corr_mepM) >= corr_cutoff)[0]]) 
# want mepM to come first in list
mepM_corr_genes = ['mepM'] + mepM_corr_genes
mepM_corr_genes = list(dict.fromkeys(mepM_corr_genes)) 

# make a correlation heatmap with just these genes
corr_mepM = tpm_df[mepM_corr_genes].corr()

# sort by descending correlation
mepM_corr_genes = corr_mepM.sort_values(by=['mepM'],ascending=False)['mepM'].index.tolist()

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

fig = sc.pl.heatmap(adata, var_names=mepM_corr_genes, 
              groupby=['strain'],
              swap_axes=True,figsize=(5,7),
              cmap='viridis',standard_scale='var') # ,save='_mepM-corr.pdf'

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;

# %% [markdown]
# ### what genes are correlated with cysW?

# %%
# which genes are correlated with ... 
this_gene = 'cysW'
tpm_df = pd.DataFrame(bdata.X,columns=bdata.var_names.tolist())
corr_ = np.array(tpm_df.corrwith(tpm_df[this_gene]))

corr_cutoff = 0.7
corr_genes = list(bdata.var_names[np.where(np.abs(corr_) >= corr_cutoff)[0]]) 
# want Actuator_YFP to come first in list
corr_genes = [this_gene] + corr_genes
corr_genes = list(dict.fromkeys(corr_genes)) 

# make a correlation heatmap with just these genes
corr_ = tpm_df[corr_genes].corr()

# sort by descending correlation
corr_genes = corr_.sort_values(by=[this_gene],ascending=False)[this_gene].index.tolist()

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

fig = sc.pl.heatmap(adata, var_names=corr_genes, 
              groupby=['strain','timepoint'],
              swap_axes=True,figsize=(20,8),
              cmap='viridis',standard_scale='var',dendrogram=False)

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;

# %%
# group by strain and plot 

plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
sc.pl.violin(adata,keys=['cysW'],groupby='strain',rotation=90) # ,save='_mepM.pdf'
plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True;

# %% [markdown]
# ### Genes which are upregulated at all timepoints

# %%
rdata = adata.copy()
from sklearn.preprocessing import RobustScaler, QuantileTransformer
transformer = QuantileTransformer(n_quantiles=700,random_state=42).fit(rdata.X)
rdata.X = transformer.transform(rdata.X)

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

fig = sc.pl.heatmap(rdata, var_names=['yjiH','yedE','yedF','hybO','hybA','hybB','ycbJ','yeeE','iraD'] + corr_genes,
                    # 'grcA','rcsA','dmsA','wcaA','wcaD','pinE','pagP' # potentially good
                                      #'rpmE','fruB','fruK','ynfK'],  # not so great
              groupby=['strain','timepoint'],
              swap_axes=True,figsize=(20,13),
              cmap='viridis',dendrogram=False) # ,save='_circuit_state_biomarkers_up.pdf'

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;
# Out:
# WARNING: saving figure to file figures/heatmap_circuit_state_biomarkers_up.pdf

# %%
# genes which are correlated with hybO
this_gene = 'cysW'
tpm_df = pd.DataFrame(bdata.X,columns=bdata.var_names.tolist())
corr_ = np.array(tpm_df.corrwith(tpm_df[this_gene]))

corr_cutoff = 0.7
corr_genes = list(bdata.var_names[np.where(np.abs(corr_) >= corr_cutoff)[0]]) 
# want Actuator_YFP to come first in list
corr_genes = [this_gene] + corr_genes
corr_genes = list(dict.fromkeys(corr_genes)) 

# make a correlation heatmap with just these genes
corr_ = tpm_df[corr_genes].corr()

# sort by descending correlation
corr_genes = corr_.sort_values(by=[this_gene],ascending=False)[this_gene].index.tolist()

# %%
corr_genes
# Out:
# ['cysW',
#  'cysJ',
#  'cysI',
#  'cysU',
#  'cysH',
#  'cysN',
#  'cysA',
#  'cysD',
#  'yciW',
#  'cysK',
#  'cysP',
#  'cysC',
#  'yeeE',
#  'yeeD',
#  'ilvX',
#  'ilvM']

# %%
# group by strain and plot 

plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
sc.pl.violin(adata,keys=['bssS'],groupby='strain',rotation=90) # ,save='_mepM.pdf'
plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True;

# %% [markdown]
# ### NAND iterate growth curves

# %%
nand_od = loadmat('GrowthCurves/NAND1_GCs.mat')['A']
tspan = np.arange(0,18,18/121)
wt_mean = np.mean(nand_od[:,[9,21,33,45]],axis=1) # no induction for all curves below
wt_std = np.std(nand_od[:,[9,21,33,45]],axis=1)
phlf_mean = np.mean(nand_od[:,[0,12,24,36]],axis=1) 
phlf_std = np.std(nand_od[:,[0,12,24,36]],axis=1) 
icar_mean = np.mean(nand_od[:,[1,13,25,37]],axis=1) 
icar_std = np.std(nand_od[:,[1,13,25,37]],axis=1)
nand_mean = np.mean(nand_od[:,[2,14,26,38]],axis=1)
nand_std = np.std(nand_od[:,[2,14,26,38]],axis=1)

# %%
savefig = False

plt.figure(figsize=(7,6))
plt.plot(tspan,wt_mean,label='MG1655 WT',lw=3,color='tab:blue') 
plt.fill_between(tspan,wt_mean-wt_std,wt_mean+wt_std,alpha=0.2,color='tab:blue')
plt.plot(tspan,phlf_mean,label='PhlF Gate',lw=3,color='tab:pink') 
plt.fill_between(tspan,phlf_mean-phlf_std,phlf_mean+phlf_std,alpha=0.15,color='tab:pink')
plt.plot(tspan,icar_mean,label='IcaR Gate',lw=3,color='tab:red') 
plt.fill_between(tspan,icar_mean-icar_std,icar_mean+icar_std,alpha=0.15,color='tab:red')
plt.plot(tspan,nand_mean,label='NAND Circuit',lw=3 ,color='tab:gray')
plt.fill_between(tspan,nand_mean-nand_std,nand_mean+nand_std,alpha=0.15,color='tab:gray')
plt.legend(frameon=False,fontsize=21,loc=(0.4,0.14))
plt.xlabel('Time (hours)',fontsize=25); plt.ylabel(r'OD$_{600}$',fontsize=29)
plt.ylim(-0.01,)
plt.xlim(0,18)
if savefig: 
    plt.savefig(figDir+'fig2/NANDiterate_gcs.pdf',bbox_inches='tight',transparent=True,dpi=300)
plt.show()

# %% [markdown]
# ### Perform PCA -> kNN -> Leiden -> UMAP analysis

# %%
sc.pp.pca(bdata,n_comps=25,random_state=0)
sc.pp.neighbors(bdata,n_neighbors=50,random_state=0)
sc.tl.leiden(bdata,resolution=1,random_state=0) 
sc.tl.umap(bdata,min_dist=1.9,random_state=0)

# %%
sc.pl.umap(bdata,color='strain',
           palette=['tab:red','tab:gray','tab:pink','tab:blue','tab:orange','tab:olive','tab:purple'],
          ) # save='_umap_by_strain.pdf'
sc.pl.umap(bdata,color='timepoint',palette=['tab:blue','tab:orange','tab:green','tab:red'],
          ) # save='_umap_by_time.pdf'
sc.pl.umap(bdata,color='leiden',legend_loc='on data',legend_fontoutline=4,legend_fontweight='heavy',
          ) # save='_umap_by_cluster.pdf'
sc.pl.umap(bdata,color='strain_input_state',
          ) # save='_umap_by_input_state.pdf'

# %% [markdown]
# ### Differential expression between cluster 1 and the rest

# %%
sc.tl.rank_genes_groups(bdata,'leiden',reference='1',method='wilcoxon',rankby_abs=True)

# %%
leiden_de_genes = np.array([])
for ii in range(len(bdata.uns['rank_genes_groups']['names'])):
    these_genes = np.array(list(bdata.uns['rank_genes_groups']['names'][ii])).reshape(-1,1)
    leiden_de_genes = np.hstack((leiden_de_genes,these_genes)) if leiden_de_genes.size else these_genes
leiden_de_genes = pd.DataFrame(leiden_de_genes,index=['0']+[str(ii) for ii in range(2,18)])

# need to remove these genes as they are the wild type comparison DEGs
remove_genes = set(list(leiden_de_genes.loc['4'][0:25]) + 
                   list(leiden_de_genes.loc['12'][0:25]) + 
                   list(leiden_de_genes.loc['11'][0:25]))

# get top 25 de genes from each cluster comparison
leiden_de_genes_list = list(np.array(list( set(np.array(leiden_de_genes.iloc[:,0:25]).flatten()) - remove_genes )))

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

from scipy.cluster.hierarchy import linkage
D = bdata[:,leiden_de_genes_list].X.copy()
D = (D - D.mean(axis=0))/D.std(axis=0)
# link = linkage(D) # D being the measurement
cg = sns.clustermap(D.T,col_cluster=True,cmap=ybp_cmap,vmin=-3,vmax=3)
plt.close()
reordered_genes = cg.dendrogram_row.reordered_ind

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/matrix.py:659: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
leiden_de_genes_reordered = [leiden_de_genes_list[ii] for ii in reordered_genes]

# %%
# z-score the gene expressions across samples
zscores = (bdata.X - bdata.X.mean(axis=0)) / (bdata.X.std(axis=0)+0.001)
zdata = bdata.copy()
zdata.X = zscores

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

sc.pl.heatmap(zdata,groupby='leiden',var_names=leiden_de_genes_reordered,
              cmap=ybp_cmap,swap_axes=True,figsize=(18,13),dendrogram=True,vmin=-2.5,vmax=2.5) # ,save='_de_genes.pdf'

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;
# Out:
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`

# %% [markdown]
# ### Differential expression at 5 hours

# %%
tdata = bdata[bdata.obs.timepoint.isin(['5.0'])].copy()

sc.tl.rank_genes_groups(tdata,'strain',groups=['MG1655_NAND_Circuit'],reference='MG1655_WT',method='wilcoxon',
                       rankby_abs=True)

pvals_adj = np.array(tdata.uns['rank_genes_groups']['pvals_adj'].astype(np.float64))
fdr = -np.log10(np.array(tdata.uns['rank_genes_groups']['pvals_adj'].astype(np.float64)))
logfcs = np.array(tdata.uns['rank_genes_groups']['logfoldchanges'].astype(np.float64))
names = (tdata.uns['rank_genes_groups']['names'])
names = [gene[0] for gene in names.tolist()]
rank_genes_df = pd.DataFrame(columns=['pvals_adj','logfcs','names','is_de'])
rank_genes_df['pvals_adj'] = pvals_adj
rank_genes_df['fdr'] = fdr
rank_genes_df['logfcs'] = logfcs
rank_genes_df['names'] = names

pval_cutoff = 0.05
logfc_cutoff = 0.5

is_de = np.array((rank_genes_df['pvals_adj'] <= pval_cutoff) & (np.abs(rank_genes_df['logfcs']) >= logfc_cutoff))*1
rank_genes_df['is_de'] = is_de
rank_genes_df.sort_values(by=['is_de','logfcs'],key=abs,ascending=False,inplace=True)
rank_genes_df.reset_index(drop=True,inplace=True)

de_genes_early = rank_genes_df[rank_genes_df['is_de']==1].names.tolist()

# %%
# rank_genes_df.to_csv('wilcoxon_5hrs_nand_vs_wt.csv',sep=',')

# %%
with open('GO_analysis_5hrs.json') as f: 
    go = json.load(f)

go_5hr = pd.DataFrame(columns=['biological_process','ngenes','gene_set','fold_enrichment','fdr'])
for ii, functional_class in enumerate(go['overrepresentation']['group']):
    this_function = functional_class['result']
    go_dict = {}
    if type(this_function) == dict: # there is no functional subclass
        if this_function['input_list']['number_in_list'] != 0:
            bp = this_function['term']['label']
            ngenes = this_function['input_list']['number_in_list']
            gene_set = this_function['input_list']['mapped_id_list']['mapped_id']
            fold_enrichment = this_function['input_list']['fold_enrichment']
            fdr = this_function['input_list']['fdr']        
    else: # type(this_function) == list # there are functional subclasses, we only care for the first one i.e. the root node 
        if this_function[0]['input_list']['number_in_list'] != 0:
            bp = this_function[0]['term']['label']
            ngenes = this_function[0]['input_list']['number_in_list']
            gene_set = this_function[0]['input_list']['mapped_id_list']['mapped_id']
            fold_enrichment = this_function[0]['input_list']['fold_enrichment']
            fdr = this_function[0]['input_list']['fdr']
    go_dict['biological_process'] = bp
    go_dict['ngenes'] = ngenes
    go_dict['gene_set'] = gene_set
    go_dict['fold_enrichment'] = fold_enrichment
    go_dict['fdr'] = fdr
    
    go_5hr = go_5hr.append(go_dict,ignore_index=True)
    
# grab all genes from gene_set in go_5hr
all_genes_go_5hr = []
for gene_set in go_5hr.gene_set:
    all_genes_go_5hr.append(gene_set)
all_genes_go_5hr = [gene for sublist in all_genes_go_5hr for gene in sublist]

# %%
go_5hr
# Out:
#                                  biological_process ngenes  \
# 0                 bacterial-type flagellum assembly     15
# 1                              nitrate assimilation     16
# 2                 colanic acid biosynthetic process     14
# 3   aromatic amino acid family biosynthetic process     15
# 4                             anaerobic respiration     34
# 5  bacterial-type flagellum-dependent cell motility     27
# 6             establishment of protein localization     36
# 7                alpha-amino acid metabolic process     60
# 8                                         transport    167
# 9                                      UNCLASSIFIED     87
#
#                                             gene_set  fold_enrichment  \
# 0  [flhA, flhB, flgA, flhD, fliG, fliI, fliK, frd...         4.784314
# 1  [narQ, narP, narV, narU, narZ, narY, narW, nrf...         4.592941
# 2  [wzc, wcaJ, wcaI, wcaG, wcaF, wcaE, cpsB, manA...         4.230341
# 3  [tyrA, aroL, tyrB, aroG, trpD, trpE, aroF, trp...         3.312217
# 4  [hybB, hybA, dcuB, hybC, yjjI, ynfE, hybO, acn...         3.200000
# 5  [frdA, frdB, frdC, flgA, fliC, flgB, fliD, flg...         3.100235
# 6  [csgE, oppC, oppD, csgF, oppF, oppA, oppB, yid...         2.222391
# 7  [cysK, hemA, cysI, dsdA, cysJ, puuA, hemF, yib...         1.739750
# 8  [ompF, csgE, csgF, dcuB, chiP, nikA, dcuC, yeb...         1.346596
# 9  [yjdM, yibN, ygbE, ycbJ, ygfF, yebE, ybhB, yea...         0.507604
#
#             fdr
# 0  4.044223e-03
# 1  3.434190e-03
# 2  1.254160e-02
# 3  3.873706e-02
# 4  1.683109e-04
# 5  2.886293e-03
# 6  1.315219e-02
# 7  1.900829e-02
# 8  1.939475e-02
# 9  4.622506e-10

# %%
# gene which is differentially expressed at only this timepoint AND belongs to a highly overenriched gene set
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 

name = 'fliK'
fig, ax = plt.subplots(figsize=(4,3))
sc.pl.umap(bdata,color=name,cmap=cmap,vmin=0.8*bdata[:,name].X.mean(axis=0),ax=ax) # ,save='_fliK.pdf'

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True;

# %%
# add biological_process to gene in rank_genes_df for coloring in volcano plot
rank_genes_bioproc = ['N/A']*len(rank_genes_df)
rank_gene_list = []
for bioproc in go_5hr.biological_process:
    for genes in go_5hr[go_5hr.biological_process.isin([bioproc])].gene_set:
        for gene in genes: 
            if gene not in rank_gene_list:
                rank_genes_bioproc[rank_genes_df[rank_genes_df.names.isin([gene])].index[0]] = bioproc
            else: 
                rank_genes_bioproc[rank_genes_df[rank_genes_df.names.isin([gene])].index[0]] = \
                                    rank_genes_bioproc[rank_genes_df[rank_genes_df.names.isin([gene])].index[0]] \
                                        + ',' + bioproc
            rank_gene_list.append(gene)
rank_genes_df['biological_process'] = rank_genes_bioproc

# %%
# assign colors to genes based on de and bioprocess
rank_genes_colors = []
rank_genes_sizes = []
bioproc_plot = 'bacterial-type flagellum assembly'
for ii in range(len(rank_genes_df)):
    gene_de = rank_genes_df.loc[ii].is_de
    bioproc = rank_genes_df.loc[ii].biological_process
    if gene_de and bioproc_plot in bioproc:
        rank_genes_colors.append(list(cmap(256)[0:3])+[1])
        rank_genes_sizes.append(1000)
    elif gene_de and bioproc_plot not in bioproc:
        rank_genes_colors.append(list(cmap(128)[0:3])+[0.4])
        rank_genes_sizes.append(100)
    elif not gene_de and bioproc_plot not in bioproc: 
        rank_genes_colors.append(list(cmap(0)[0:3])+[.55])
        rank_genes_sizes.append(10)

# %%
savefig = False

plt.figure(figsize=(4,3))
sns.scatterplot(x=rank_genes_df['logfcs'][2:],y=rank_genes_df['fdr'][2:],c=rank_genes_colors[2:],size=rank_genes_sizes[2:],
                legend=False,linewidth=0.2,edgecolor='w')
plt.xlabel(r'$\mathrm{log}_2$ fold change',fontsize=25)
plt.ylabel(r'-$\mathrm{log}_{10}(p_{\mathrm{adj}})$',fontsize=29)
plt.plot([],[],'o',color=cmap(256),label='flagellum assembly')
plt.legend(frameon=False,fontsize=22,loc=(-0.1,1),markerscale=1.2,markerfirst=False,handletextpad=0)
plt.xlim(-8,7)
plt.ylim(1,9.1)
if savefig: 
    plt.savefig(figDir+'fig2/lfcs_5hr.pdf',bbox_inches='tight',transparent=True,dpi=300)
plt.show()

# %% [markdown]
# ### Differential expression at 6.5/8.0 hours

# %%
tdata = bdata[bdata.obs.timepoint.isin(['6.5','8.0'])].copy()

sc.tl.rank_genes_groups(tdata,'strain',groups=['MG1655_NAND_Circuit'],reference='MG1655_WT',method='wilcoxon',
                       rankby_abs=True)

pvals_adj = np.array(tdata.uns['rank_genes_groups']['pvals_adj'].astype(np.float64))
fdr = -np.log10(np.array(tdata.uns['rank_genes_groups']['pvals_adj'].astype(np.float64)))
logfcs = np.array(tdata.uns['rank_genes_groups']['logfoldchanges'].astype(np.float64))
names = (tdata.uns['rank_genes_groups']['names'])
names = [gene[0] for gene in names.tolist()]
rank_genes_df = pd.DataFrame(columns=['pvals_adj','logfcs','names','is_de'])
rank_genes_df['pvals_adj'] = pvals_adj
rank_genes_df['fdr'] = fdr
rank_genes_df['logfcs'] = logfcs
rank_genes_df['names'] = names

pval_cutoff = 0.05
logfc_cutoff = 0.5

is_de = np.array((rank_genes_df['pvals_adj'] <= pval_cutoff) & (np.abs(rank_genes_df['logfcs']) >= logfc_cutoff))*1
rank_genes_df['is_de'] = is_de
rank_genes_df.sort_values(by=['is_de','logfcs'],key=abs,ascending=False,inplace=True)
rank_genes_df.reset_index(drop=True,inplace=True)

de_genes_mid = rank_genes_df[rank_genes_df['is_de']==1].names.tolist()

# %%
# rank_genes_df.to_csv('wilcoxon_6and8hrs_nand_vs_wt.csv',sep=',')

# %%
with open('GO_analysis_6and8hrs.json') as f: 
    go = json.load(f)

go_6and8hr = pd.DataFrame(columns=['biological_process','ngenes','gene_set','fold_enrichment','fdr'])
for ii, functional_class in enumerate(go['overrepresentation']['group']):
    this_function = functional_class['result']
    go_dict = {}
    if type(this_function) == dict: # there is no functional subclass
        if this_function['input_list']['number_in_list'] != 0:
            bp = this_function['term']['label']
            ngenes = this_function['input_list']['number_in_list']
            gene_set = this_function['input_list']['mapped_id_list']['mapped_id']
            fold_enrichment = this_function['input_list']['fold_enrichment']
            fdr = this_function['input_list']['fdr']        
    else: # type(this_function) == list # there are functional subclasses, we only care for the first one i.e. the root node 
        if this_function[0]['input_list']['number_in_list'] != 0:
            bp = this_function[0]['term']['label']
            ngenes = this_function[0]['input_list']['number_in_list']
            gene_set = this_function[0]['input_list']['mapped_id_list']['mapped_id']
            fold_enrichment = this_function[0]['input_list']['fold_enrichment']
            fdr = this_function[0]['input_list']['fdr']
    go_dict['biological_process'] = bp
    go_dict['ngenes'] = ngenes
    go_dict['gene_set'] = gene_set
    go_dict['fold_enrichment'] = fold_enrichment
    go_dict['fdr'] = fdr
    
    go_6and8hr = go_6and8hr.append(go_dict,ignore_index=True)

# %%
go_6and8hr
# Out:
#                                  biological_process ngenes  \
# 0   slime layer polysaccharide biosynthetic process      9
# 1                         hexitol metabolic process      9
# 2                 colanic acid biosynthetic process     15
# 3       reactive nitrogen species metabolic process     14
# 4                      neutral amino acid transport     18
# 5                              cellular respiration     37
# 6          cellular amino acid biosynthetic process     42
# 7                                   anion transport     53
# 8                alpha-amino acid metabolic process     54
# 9                           transmembrane transport    131
# 10                       macromolecule modification     20
# 11                                 ncRNA processing      4
# 12                                DNA recombination      4
# 13                                DNA recombination      4
#
#                                              gene_set  fold_enrichment  \
# 0   [wcaL, wcaK, wcaI, wcaF, wcaE, wcaD, wcaC, wca...         5.812941
# 1   [gatZ, uxaB, gatA, uxuB, gatB, gatD, mtlD, yei...         5.284492
# 2   [wzc, wcaJ, wcaI, galE, wcaG, wcaF, wcaE, cpsB...         5.099071
# 3   [narV, narU, narZ, narY, narX, hmp, narW, norW...         3.767647
# 4   [livK, alaE, livJ, sdaC, livM, gltL, glnH, rht...         3.321681
# 5   [hybB, hybA, dcuB, gltA, hybC, aceK, cyoA, yjj...         2.096285
# 6   [hisB, ilvC, hisC, hisD, leuL, argD, cysJ, met...         1.883824
# 7   [dcuB, nikA, dcuC, cysA, chaA, glnH, cadB, arg...         1.773667
# 8   [leuL, argD, cysJ, puuA, gadA, gadB, glnA, yib...         1.761497
# 9   [ompF, csgE, yhhQ, csgF, dcuB, yhhS, nikA, dcu...         1.419641
# 10  [ybeT, wzc, envZ, aceK, yedV, hsdR, yfhL, narX...         0.478431
# 11                           [cmoB, yfhL, iscS, yceA]         0.228631
# 12                           [pinE, fimB, rmuC, ybfD]         0.220814
# 13                           [pinE, fimB, rmuC, ybfD]         0.220814
#
#          fdr
# 0   0.037756
# 1   0.046223
# 2   0.004894
# 3   0.035845
# 4   0.024839
# 5   0.036012
# 6   0.047275
# 7   0.042935
# 8   0.039479
# 9   0.025266
# 10  0.042771
# 11  0.043007
# 12  0.041726
# 13  0.041726

# %%
# grab all genes from gene_set in go_6and8hr
all_genes_go_6and8hr = []
for gene_set in go_6and8hr.gene_set:
    all_genes_go_6and8hr.append(gene_set)
all_genes_go_6and8hr = [gene for sublist in all_genes_go_6and8hr for gene in sublist]

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 

name = 'putA' # 'putA' # 'modB' 
fig, ax = plt.subplots(figsize=(4,3))
sc.pl.umap(bdata,color=name,cmap=cmap,vmin=0.85*bdata[:,name].X.mean(axis=0)
           ,ax=ax) # ,save='_putA.pdf'

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True;

# %%
# add biological_process to gene in rank_genes_df for coloring in volcano plot
rank_genes_bioproc = ['N/A']*len(rank_genes_df)
rank_gene_list = []
for bioproc in go_6and8hr.biological_process:
    for genes in go_6and8hr[go_6and8hr.biological_process.isin([bioproc])].gene_set:
        for gene in genes: 
            if gene not in rank_gene_list:
                rank_genes_bioproc[rank_genes_df[rank_genes_df.names.isin([gene])].index[0]] = bioproc
            else: 
                rank_genes_bioproc[rank_genes_df[rank_genes_df.names.isin([gene])].index[0]] = \
                                    rank_genes_bioproc[rank_genes_df[rank_genes_df.names.isin([gene])].index[0]] \
                                        + ',' + bioproc
            rank_gene_list.append(gene)
rank_genes_df['biological_process'] = rank_genes_bioproc

# %%
# assign colors to genes based on de and bioprocess
rank_genes_colors = []
rank_genes_sizes = []
bioproc_plot = 'cellular amino acid biosynthetic process'
for ii in range(len(rank_genes_df)):
    gene_de = rank_genes_df.loc[ii].is_de
    bioproc = rank_genes_df.loc[ii].biological_process
    if gene_de and bioproc_plot in bioproc:
        rank_genes_colors.append(list(cmap(256)[0:3])+[1])
        rank_genes_sizes.append(1000)
    elif gene_de and bioproc_plot not in bioproc:
        rank_genes_colors.append(list(cmap(128)[0:3])+[0.4])
        rank_genes_sizes.append(100)
    elif not gene_de and bioproc_plot not in bioproc: 
        rank_genes_colors.append(list(cmap(0)[0:3])+[.55])
        rank_genes_sizes.append(10)

# %%
savefig = False

plt.figure(figsize=(4,3))
sns.scatterplot(x=rank_genes_df['logfcs'][2:],y=rank_genes_df['fdr'][2:],c=rank_genes_colors[2:],size=rank_genes_sizes[2:],
                legend=False,linewidth=0.2,edgecolor='w')
plt.xlabel(r'$\mathrm{log}_2$ fold change',fontsize=25)
plt.ylabel(r'-$\mathrm{log}_{10}(p_{\mathrm{adj}})$',fontsize=29)
plt.plot([],[],'o',color=cmap(256),label='amino acid biosynthesis')
plt.legend(frameon=False,fontsize=22,loc=(-0.2,1),markerscale=1.2,markerfirst=False,handletextpad=0)
plt.xlim(-10,7.5)
plt.ylim(1,)
if savefig: 
    plt.savefig(figDir+'fig2/lfcs_6and8hr.pdf',bbox_inches='tight',transparent=True,dpi=300)
plt.show()

# %% [markdown]
# ### Differential expression at 18 hours

# %%
tdata = bdata[bdata.obs.timepoint.isin(['18.0'])].copy()

sc.tl.rank_genes_groups(tdata,'strain',groups=['MG1655_NAND_Circuit'],reference='MG1655_WT',method='wilcoxon',
                       rankby_abs=True)

pvals_adj = np.array(tdata.uns['rank_genes_groups']['pvals_adj'].astype(np.float64))
fdr = -np.log10(np.array(tdata.uns['rank_genes_groups']['pvals_adj'].astype(np.float64)))
logfcs = np.array(tdata.uns['rank_genes_groups']['logfoldchanges'].astype(np.float64))
names = (tdata.uns['rank_genes_groups']['names'])
names = [gene[0] for gene in names.tolist()]
rank_genes_df = pd.DataFrame(columns=['pvals_adj','logfcs','names','is_de'])
rank_genes_df['pvals_adj'] = pvals_adj
rank_genes_df['fdr'] = fdr
rank_genes_df['logfcs'] = logfcs
rank_genes_df['names'] = names

pval_cutoff = 0.05
logfc_cutoff = 0.5

is_de = np.array((rank_genes_df['pvals_adj'] <= pval_cutoff) & (np.abs(rank_genes_df['logfcs']) >= logfc_cutoff))*1
rank_genes_df['is_de'] = is_de
rank_genes_df.sort_values(by=['is_de','logfcs'],key=abs,ascending=False,inplace=True)
rank_genes_df.reset_index(drop=True,inplace=True)

de_genes_mid = rank_genes_df[rank_genes_df['is_de']==1].names.tolist()

# %%
# rank_genes_df.to_csv('wilcoxon_18hrs_nand_vs_wt.csv',sep=',')

# %%
with open('GO_analysis_18hrs.json') as f: 
    go = json.load(f)

go_18hr = pd.DataFrame(columns=['biological_process','ngenes','gene_set','fold_enrichment','fdr'])
for ii, functional_class in enumerate(go['overrepresentation']['group']):
    this_function = functional_class['result']
    go_dict = {}
    if type(this_function) == dict: # there is no functional subclass
        if this_function['input_list']['number_in_list'] != 0:
            bp = this_function['term']['label']
            ngenes = this_function['input_list']['number_in_list']
            gene_set = this_function['input_list']['mapped_id_list']['mapped_id']
            fold_enrichment = this_function['input_list']['fold_enrichment']
            fdr = this_function['input_list']['fdr']        
    else: # type(this_function) == list # there are functional subclasses, we only care for the first one i.e. the root node 
        if this_function[0]['input_list']['number_in_list'] != 0:
            bp = this_function[0]['term']['label']
            ngenes = this_function[0]['input_list']['number_in_list']
            gene_set = this_function[0]['input_list']['mapped_id_list']['mapped_id']
            fold_enrichment = this_function[0]['input_list']['fold_enrichment']
            fdr = this_function[0]['input_list']['fdr']
    go_dict['biological_process'] = bp
    go_dict['ngenes'] = ngenes
    go_dict['gene_set'] = gene_set
    go_dict['fold_enrichment'] = fold_enrichment
    go_dict['fdr'] = fdr
    
    go_18hr = go_18hr.append(go_dict,ignore_index=True)

# %%
go_18hr
# Out:
#                       biological_process ngenes  \
# 0  hydrogen sulfide biosynthetic process      6
# 1                       glyoxylate cycle      6
# 2               tricarboxylic acid cycle     15
# 3     alpha-amino acid metabolic process     30
#
#                                             gene_set  fold_enrichment  \
# 0               [cysI, cysJ, cysH, cysC, cysD, cysN]        14.837838
# 1                [iclR, aceB, aceA, aceK, icd, acnB]        11.128378
# 2  [gltA, aceK, icd, aspA, aceB, aceA, sucC, sucD...         7.674744
# 3  [ilvD, cysK, cysI, leuL, cysJ, ilvE, puuA, gad...         2.248157
#
#         fdr
# 0  0.042066
# 1  0.046003
# 2  0.000097
# 3  0.050000

# %%
# grab all genes from gene_set in go_18hr
all_genes_go_18hr = []
for gene_set in go_18hr.gene_set:
    all_genes_go_18hr.append(gene_set)
all_genes_go_18hr = [gene for sublist in all_genes_go_18hr for gene in sublist]

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 

name = 'icd'
fig, ax = plt.subplots(figsize=(4,3))
sc.pl.umap(bdata,color=name,cmap=cmap,vmin=0.75*bdata[:,name].X.mean(axis=0),ax=ax) # ,save='_icd.pdf' 

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True;

# %%
# add biological_process to gene in rank_genes_df for coloring in volcano plot
rank_genes_bioproc = ['N/A']*len(rank_genes_df)
rank_gene_list = []
for bioproc in go_18hr.biological_process:
    for genes in go_18hr[go_18hr.biological_process.isin([bioproc])].gene_set:
        for gene in genes: 
            if gene not in rank_gene_list:
                rank_genes_bioproc[rank_genes_df[rank_genes_df.names.isin([gene])].index[0]] = bioproc
            else: 
                rank_genes_bioproc[rank_genes_df[rank_genes_df.names.isin([gene])].index[0]] = \
                                    rank_genes_bioproc[rank_genes_df[rank_genes_df.names.isin([gene])].index[0]] \
                                        + ',' + bioproc
            rank_gene_list.append(gene)
rank_genes_df['biological_process'] = rank_genes_bioproc

# %%
# assign colors to genes based on de and bioprocess
rank_genes_colors = []
rank_genes_sizes = []
bioproc_plot = 'tricarboxylic acid cycle'
for ii in range(len(rank_genes_df)):
    gene_de = rank_genes_df.loc[ii].is_de
    bioproc = rank_genes_df.loc[ii].biological_process
    if gene_de and bioproc_plot in bioproc:
        rank_genes_colors.append(list(cmap(256)[0:3])+[1])
        rank_genes_sizes.append(1000)
    elif gene_de and bioproc_plot not in bioproc:
        rank_genes_colors.append(list(cmap(128)[0:3])+[0.4])
        rank_genes_sizes.append(100)
    elif not gene_de and bioproc_plot not in bioproc: 
        rank_genes_colors.append(list(cmap(0)[0:3])+[.55])
        rank_genes_sizes.append(10)

# %%
savefig = False

plt.figure(figsize=(4,3))
sns.scatterplot(x=rank_genes_df['logfcs'][2:],y=rank_genes_df['fdr'][2:],c=rank_genes_colors[2:],size=rank_genes_sizes[2:],
                legend=False,linewidth=0.2,edgecolor='w')
plt.xlabel(r'$\mathrm{log}_2$ fold change',fontsize=25)
plt.ylabel(r'-$\mathrm{log}_{10}(p_{\mathrm{adj}})$',fontsize=29)
plt.plot([],[],'o',color=cmap(256),label='tricarboxylic acid cycle')
plt.legend(frameon=False,fontsize=22,loc=(-0.2,1),markerscale=1.2,markerfirst=False,handletextpad=0)
plt.xlim(-10,8)
plt.ylim(1,9.5)
if savefig: 
    plt.savefig(figDir+'fig2/lfcs_18hr.pdf',bbox_inches='tight',transparent=True,dpi=300)
plt.show()

# %% [markdown]
# ### DEGs only at one timepoint

# %%
set(de_genes_early) - set(de_genes_mid) - set(de_genes_late)
# Out:
# {'acnA',
#  'actP',
#  'aegA',
#  'agaS',
#  'amiA',
#  'amiC',
#  'ampH',
#  'amtB',
#  'ansB',
#  'aphA',
#  'arnF',
#  'aroF',
#  'aroL',
#  'aroP',
#  'asnA',
#  'asnS',
#  'astE',
#  'bamD',
#  'bcp',
#  'bfr',
#  'bioD',
#  'btuE',
#  'caiA',
#  'caiB',
#  'caiE',
#  'ccmA',
#  'cheB',
#  'chiP',
#  'citE',
#  'cmoA',
#  'cmtB',
#  'cobS',
#  'codA',
#  'cptA',
#  'crfC',
#  'dacA',
#  'dctA',
#  'ddpC',
#  'dhaK',
#  'dhaL',
#  'dusA',
#  'efeO',
#  'emrD',
#  'emrY',
#  'emtA',
#  'entB',
#  'entC',
#  'entE',
#  'entF',
#  'entH',
#  'entS',
#  'exbD',
#  'fadH',
#  'fadL',
#  'fdhF',
#  'fdnG',
#  'fecE',
#  'fepA',
#  'fepB',
#  'fepE',
#  'fes',
#  'fhuE',
#  'fimA',
#  'fimC',
#  'fimD',
#  'fimH',
#  'fimI',
#  'fkpA',
#  'flgA',
#  'flgB',
#  'flgC',
#  'flgD',
#  'flgE',
#  'flgF',
#  'flgG',
#  'flgH',
#  'flgI',
#  'flgJ',
#  'flgK',
#  'flgL',
#  'flhA',
#  'flhB',
#  'flhD',
#  'flhE',
#  'fliA',
#  'fliC',
#  'fliE',
#  'fliF',
#  'fliG',
#  'fliH',
#  'fliI',
#  'fliK',
#  'fliL',
#  'fliN',
#  'fliO',
#  'fliP',
#  'fliQ',
#  'fliS',
#  'fliZ',
#  'fnr',
#  'folE',
#  'frc',
#  'frdD',
#  'fsaB',
#  'fucA',
#  'fucO',
#  'fumB',
#  'ghoS',
#  'ghoT',
#  'glyA',
#  'gntT',
#  'gpmA',
#  'gspL',
#  'gtrA',
#  'hcp',
#  'hcr',
#  'hemF',
#  'hisJ',
#  'hsrA',
#  'hypD',
#  'hypF',
#  'iadA',
#  'ibaG',
#  'idnD',
#  'idnK',
#  'ilvB',
#  'ivbL',
#  'kbaZ',
#  'kdpA',
#  'kefF',
#  'lamB',
#  'ldtB',
#  'leuO',
#  'malF',
#  'malM',
#  'mcrB',
#  'mepS',
#  'metJ',
#  'mglA',
#  'mglB',
#  'mglC',
#  'mioC',
#  'mipA',
#  'mltB',
#  'mltD',
#  'mntH',
#  'mokC',
#  'mrdA',
#  'msbA',
#  'mtr',
#  'murJ',
#  'murQ',
#  'napA',
#  'napC',
#  'napG',
#  'narH',
#  'narI',
#  'narJ',
#  'narP',
#  'ndh',
#  'nemA',
#  'nfuA',
#  'nikB',
#  'nikC',
#  'nikD',
#  'nrfA',
#  'nrfB',
#  'nrfC',
#  'nuoL',
#  'ompA',
#  'oppC',
#  'oppD',
#  'oppF',
#  'pepE',
#  'pheM',
#  'potF',
#  'potH',
#  'pqqL',
#  'proY',
#  'ravA',
#  'rcnB',
#  'rhtA',
#  'ridA',
#  'rihC',
#  'rimO',
#  'rlmA',
#  'rnd',
#  'rnlA',
#  'rnpA',
#  'rpoE',
#  'rpsU',
#  'rseA',
#  'rseB',
#  'rseC',
#  'rsmF',
#  'rsuA',
#  'rsxA',
#  'rutB',
#  'rutD',
#  'sbmA',
#  'sdhE',
#  'serC',
#  'shiA',
#  'sixA',
#  'sufA',
#  'sufB',
#  'sufC',
#  'sufD',
#  'sufE',
#  'sufS',
#  'tap',
#  'tar',
#  'tatC',
#  'tdcB',
#  'thiC',
#  'thiE',
#  'thiF',
#  'thiH',
#  'thiS',
#  'thyA',
#  'tolQ',
#  'torS',
#  'torT',
#  'tqsA',
#  'treB',
#  'trpE',
#  'trpL',
#  'trpR',
#  'tsaA',
#  'tusA',
#  'tyrA',
#  'tyrB',
#  'tyrP',
#  'ubiG',
#  'udk',
#  'ulaB',
#  'uspC',
#  'uspG',
#  'wzzB',
#  'xisE',
#  'xseA',
#  'xylF',
#  'yacL',
#  'yafK',
#  'yahN',
#  'yaiV',
#  'yaiY',
#  'yajI',
#  'ybcN',
#  'ybdZ',
#  'ybjE',
#  'ybjG',
#  'ybjJ',
#  'ycaD',
#  'ycbK',
#  'yccM',
#  'ycdU',
#  'yciE',
#  'yciF',
#  'ydcR',
#  'yddB',
#  'ydeI',
#  'ydiL',
#  'ydiY',
#  'ydjI',
#  'ydjX',
#  'ydjZ',
#  'yebK',
#  'yebQ',
#  'yecR',
#  'yedA',
#  'yegQ',
#  'yehC',
#  'yehY',
#  'yeiB',
#  'yeiR',
#  'yfbS',
#  'yfcF',
#  'yfeC',
#  'yfeD',
#  'yfeH',
#  'yfeK',
#  'yfiL',
#  'yfjH',
#  'yfjX',
#  'ygcP',
#  'ygfF',
#  'ygiM',
#  'ygiV',
#  'ygiW',
#  'yhbO',
#  'yhbS',
#  'yhbT',
#  'yhbV',
#  'yhcC',
#  'yhhA',
#  'yhiI',
#  'yhjA',
#  'yhjJ',
#  'yiaD',
#  'yiaJ',
#  'yidC',
#  'yidD',
#  'yidF',
#  'yieP',
#  'yigM',
#  'yihL',
#  'yihM',
#  'yiiS',
#  'yjcZ',
#  'yjgL',
#  'yjhG',
#  'yjiY',
#  'yjjW',
#  'yjjZ',
#  'yliF',
#  'ymgJ',
#  'yncE',
#  'ynhF',
#  'ypeC',
#  'yqiI',
#  'yqjH',
#  'zraS'}

# %%
go_18hr
# Out:
#                       biological_process ngenes  \
# 0  hydrogen sulfide biosynthetic process      6
# 1                       glyoxylate cycle      6
# 2               tricarboxylic acid cycle     15
# 3     alpha-amino acid metabolic process     30
#
#                                             gene_set  fold_enrichment  \
# 0               [cysI, cysJ, cysH, cysC, cysD, cysN]        14.837838
# 1                [iclR, aceB, aceA, aceK, icd, acnB]        11.128378
# 2  [gltA, aceK, icd, aspA, aceB, aceA, sucC, sucD...         7.674744
# 3  [ilvD, cysK, cysI, leuL, cysJ, ilvE, puuA, gad...         2.248157
#
#         fdr
# 0  0.042066
# 1  0.046003
# 2  0.000097
# 3  0.050000

# %%
go_6and8hr
# Out:
#                                  biological_process ngenes  \
# 0   slime layer polysaccharide biosynthetic process      9
# 1                         hexitol metabolic process      9
# 2                 colanic acid biosynthetic process     15
# 3       reactive nitrogen species metabolic process     14
# 4                      neutral amino acid transport     18
# 5                              cellular respiration     37
# 6          cellular amino acid biosynthetic process     42
# 7                                   anion transport     53
# 8                alpha-amino acid metabolic process     54
# 9                           transmembrane transport    131
# 10                       macromolecule modification     20
# 11                                 ncRNA processing      4
# 12                                DNA recombination      4
# 13                                DNA recombination      4
#
#                                              gene_set  fold_enrichment  \
# 0   [wcaL, wcaK, wcaI, wcaF, wcaE, wcaD, wcaC, wca...         5.812941
# 1   [gatZ, uxaB, gatA, uxuB, gatB, gatD, mtlD, yei...         5.284492
# 2   [wzc, wcaJ, wcaI, galE, wcaG, wcaF, wcaE, cpsB...         5.099071
# 3   [narV, narU, narZ, narY, narX, hmp, narW, norW...         3.767647
# 4   [livK, alaE, livJ, sdaC, livM, gltL, glnH, rht...         3.321681
# 5   [hybB, hybA, dcuB, gltA, hybC, aceK, cyoA, yjj...         2.096285
# 6   [hisB, ilvC, hisC, hisD, leuL, argD, cysJ, met...         1.883824
# 7   [dcuB, nikA, dcuC, cysA, chaA, glnH, cadB, arg...         1.773667
# 8   [leuL, argD, cysJ, puuA, gadA, gadB, glnA, yib...         1.761497
# 9   [ompF, csgE, yhhQ, csgF, dcuB, yhhS, nikA, dcu...         1.419641
# 10  [ybeT, wzc, envZ, aceK, yedV, hsdR, yfhL, narX...         0.478431
# 11                           [cmoB, yfhL, iscS, yceA]         0.228631
# 12                           [pinE, fimB, rmuC, ybfD]         0.220814
# 13                           [pinE, fimB, rmuC, ybfD]         0.220814
#
#          fdr
# 0   0.037756
# 1   0.046223
# 2   0.004894
# 3   0.035845
# 4   0.024839
# 5   0.036012
# 6   0.047275
# 7   0.042935
# 8   0.039479
# 9   0.025266
# 10  0.042771
# 11  0.043007
# 12  0.041726
# 13  0.041726

# %%
go_5hr
# Out:
#                                  biological_process ngenes  \
# 0                 bacterial-type flagellum assembly     15
# 1                              nitrate assimilation     16
# 2                 colanic acid biosynthetic process     14
# 3   aromatic amino acid family biosynthetic process     15
# 4                             anaerobic respiration     34
# 5  bacterial-type flagellum-dependent cell motility     27
# 6             establishment of protein localization     36
# 7                alpha-amino acid metabolic process     60
# 8                                         transport    167
# 9                                      UNCLASSIFIED     87
#
#                                             gene_set  fold_enrichment  \
# 0  [flhA, flhB, flgA, flhD, fliG, fliI, fliK, frd...         4.784314
# 1  [narQ, narP, narV, narU, narZ, narY, narW, nrf...         4.592941
# 2  [wzc, wcaJ, wcaI, wcaG, wcaF, wcaE, cpsB, manA...         4.230341
# 3  [tyrA, aroL, tyrB, aroG, trpD, trpE, aroF, trp...         3.312217
# 4  [hybB, hybA, dcuB, hybC, yjjI, ynfE, hybO, acn...         3.200000
# 5  [frdA, frdB, frdC, flgA, fliC, flgB, fliD, flg...         3.100235
# 6  [csgE, oppC, oppD, csgF, oppF, oppA, oppB, yid...         2.222391
# 7  [cysK, hemA, cysI, dsdA, cysJ, puuA, hemF, yib...         1.739750
# 8  [ompF, csgE, csgF, dcuB, chiP, nikA, dcuC, yeb...         1.346596
# 9  [yjdM, yibN, ygbE, ycbJ, ygfF, yebE, ybhB, yea...         0.507604
#
#             fdr
# 0  4.044223e-03
# 1  3.434190e-03
# 2  1.254160e-02
# 3  3.873706e-02
# 4  1.683109e-04
# 5  2.886293e-03
# 6  1.315219e-02
# 7  1.900829e-02
# 8  1.939475e-02
# 9  4.622506e-10

# %%
set.intersection(set(de_genes_mid) - set(de_genes_early) - set(de_genes_late), set(go_6and8hr.gene_set[6]) )
# Out:
# {'alaA',
#  'argD',
#  'argI',
#  'dadX',
#  'hisB',
#  'hisC',
#  'hisD',
#  'hisF',
#  'hisG',
#  'hisH',
#  'hisI',
#  'lysA',
#  'metB',
#  'metL',
#  'putA'}

# %%
set.intersection(set(de_genes_late) - set(de_genes_early) - set(de_genes_mid), set(go_18hr.gene_set[2]) )
# Out:
# {'icd'}

# %% [markdown]
# ### Which genes are differentially expressed at all timepoints

# %%
de_genes = list(set.intersection(set(de_genes_early), set(de_genes_mid), set(de_genes_late)))

# %%
de_genes
# Out:
# ['yedR',
#  'glnK',
#  'rsd',
#  'yeeE',
#  'ynfK',
#  'rbsD',
#  'ompR',
#  'kgtP',
#  'yjiH',
#  'yncD',
#  'mqsA',
#  'ygeV',
#  'yeaC',
#  'ygbE',
#  'yedE',
#  'ompF',
#  'hyaB',
#  'purE',
#  'narZ',
#  'fruK',
#  'znuB',
#  'fruB',
#  'nrdI',
#  'cysA',
#  'yibF',
#  'ykgM',
#  'ycgM',
#  'rihA',
#  'hyaC',
#  'appY',
#  'inaA',
#  'yhfZ',
#  'yecE',
#  'dctR',
#  'yfcZ',
#  'ykgO',
#  'sucC',
#  'wcaA',
#  'astC',
#  'ycbJ',
#  'narU',
#  'moaB',
#  'ydiE',
#  'nrdH',
#  'pinE',
#  'cysW',
#  'nrdD',
#  'ygiS',
#  'pagP',
#  'hybO',
#  'puuA',
#  'pspD',
#  'ydcH',
#  'hyaE',
#  'yedF',
#  'ykgR',
#  'wcaD',
#  'livF',
#  'ymdF',
#  'ibpB',
#  'iraD',
#  'cysP',
#  'ymgD',
#  'trpB',
#  'bssS',
#  'znuA',
#  'psiE',
#  'pspE',
#  'nudE',
#  'znuC',
#  'aspA',
#  'hyaA',
#  'degP',
#  'nadA',
#  'ycgL',
#  'purR',
#  'gcd',
#  'rpmE',
#  'yqjA',
#  'focA',
#  'iscR',
#  'yfhL',
#  'sdhC',
#  'nrdG',
#  'yagE',
#  'yeeD',
#  'spy',
#  'yfcC',
#  'grcA',
#  'yhfY',
#  'purM',
#  'dmsA',
#  'fruA',
#  'yfiM',
#  'fucP',
#  'raiA',
#  'astA',
#  'sdhD',
#  'ilvN',
#  'ybaA',
#  'csgE',
#  'tdcA',
#  'adiY',
#  'lgoR',
#  'moaE',
#  'narY',
#  'yahM',
#  'trpC',
#  'ompC',
#  'csgD',
#  'cysJ',
#  'yhbU',
#  'cysU',
#  'yjdM',
#  'dppB',
#  'zinT',
#  'mepM',
#  'serA',
#  'ykgL',
#  'envZ',
#  'gatA',
#  'nrdF',
#  'nrdE',
#  'yjbB',
#  'greB',
#  'pspG',
#  'rcsA',
#  'dcuB',
#  'mocA',
#  'pliG',
#  'ydeA',
#  'ydcI',
#  'narW',
#  'gatB',
#  'puuC',
#  'yqeC',
#  'yhiD',
#  'gatZ',
#  'tnaC',
#  'sodB',
#  'fecA',
#  'pspB']

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 

name = 'hybO' # 'putA' # 'modB' 
fig, ax = plt.subplots()
sc.pl.umap(bdata,color=name,cmap=cmap,vmin=0.85*bdata[:,name].X.mean(axis=0)
           ,ax=ax) 

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True;

# %%
rank_genes_df[rank_genes_df.names.isin(de_genes)].sort_values('logfcs',ascending=False)
# Out:
#        pvals_adj     logfcs names  is_de        fdr  \
# 19  2.207591e-14   3.544442  hybO      1  13.656081
# 22  1.843140e-12   3.441500  fruB      1  11.734442
# 33  1.792191e-13   2.865097  gatB      1  12.746616
# 45  9.678799e-15   2.400644  grcA      1  14.014179
# 51  3.869536e-02   2.312498  tnaC      1   1.412341
# ..           ...        ...   ...    ...        ...
# 4   3.210819e-15  -9.394563  zinT      1  14.493384
# 3   3.210819e-15 -10.453135  ykgO      1  14.493384
# 2   3.210819e-15 -10.486200  ykgM      1  14.493384
# 1   3.210819e-15 -36.678780  fecA      1  14.493384
# 0   3.210819e-15 -39.359268   rsd      1  14.493384
#
#                                    biological_process
# 19                               cellular respiration
# 22                            transmembrane transport
# 33  hexitol metabolic process,transmembrane transport
# 45                 alpha-amino acid metabolic process
# 51                                                N/A
# ..                                                ...
# 4                                                 N/A
# 3                                                 N/A
# 2                                                 N/A
# 1                                                 N/A
# 0                                                 N/A
#
# [142 rows x 6 columns]

# %% [markdown]
# ### Which genes correlate best with YFP expression?
# Or other interesting genes

# %%
# which genes are correlated with yfp 
this_gene = 'ompR'
tpm_df = pd.DataFrame(adata.X,columns=adata.var_names.tolist())
corr_ = np.array(tpm_df.corrwith(tpm_df[this_gene]))

corr_cutoff = 0.7
corr_genes = list(adata.var_names[np.where(np.abs(corr_) >= corr_cutoff)[0]]) 
# want Actuator_YFP to come first in list
corr_genes = [this_gene] + corr_genes
corr_genes = list(dict.fromkeys(corr_genes)) 

# make a correlation heatmap with just these genes
corr_ = tpm_df[corr_genes].corr()

# sort by descending correlation
corr_genes = corr_.sort_values(by=[this_gene],ascending=False)[this_gene].index.tolist()

# %%
corr_genes
# Out:
# ['ompR',
#  'rsd',
#  'fecA',
#  'envZ',
#  'dtpA',
#  'csgD',
#  'greB',
#  'ymdF',
#  'narZ',
#  'rsd_2',
#  'fecA_2',
#  'Sensor_AraC',
#  'Sensor_LacI']

# %%
sns.heatmap(corr_,cmap='RdBu',center=0,vmin=-1,vmax=1)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
# ax.set_xlim(5,11)
# ax.set_ylim(1,8)
sc.pl.scatter(adata,x='ompR',y='narZ',color='strain',ax=ax)

# %% [markdown]
# ### next

# %%
sc.pl.rank_genes_groups_violin(bdata,gene_names=['groS','groL','rpoH'], groups=['0'])

# %% [markdown]
# The groSL activation and slight upreuglation of rpoH (heat shock sigma factor) may represent a general stress response activation at this timepoint

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

dges = ['zntR','zur','csgA','cheW','recX','mtlD','uxuB','ompR','narZ'] 
fig = sc.pl.heatmap(adata, var_names=dges, 
              groupby=['strain','timepoint'],
              swap_axes=True,figsize=(15,len(dges)//1),
              cmap='viridis',standard_scale='var')

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

dges = ['gad'+end for end in 'ABCEWX'] 
fig = sc.pl.heatmap(adata, var_names=dges, 
              groupby=['strain','timepoint'],
              swap_axes=True,figsize=(15,6),
              cmap='viridis',standard_scale='var')

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;

# %%
plt.rcParams['xtick.minor.visible'] = False; plt.rcParams['ytick.minor.visible'] = False; 
plt.rcParams['axes.spines.right'] = True; plt.rcParams['axes.spines.top'] = True; 

dges = ['wca'+end for end in 'ABCEFGIJK'] + ['wzb','gmd','wzc','wzxC','cpsB']
fig = sc.pl.heatmap(adata, var_names=dges, 
              groupby=['strain'],
              swap_axes=True,figsize=(9,6),
              cmap='viridis',standard_scale='var')

plt.rcParams['xtick.minor.visible'] = True; plt.rcParams['ytick.minor.visible'] = True; 
plt.rcParams['axes.spines.right'] = False; plt.rcParams['axes.spines.top'] = False;

# %%
sc.pl.violin(bdata,keys=['recX'],groupby='strain',rotation=90)

# %%
name = 'cheW'
sc.pl.umap(bdata,color=name,cmap=cmap,vmin=0.9*bdata[:,name].X.mean(axis=0))
